# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv

sit = '/home/master/Jibum/Motion_Show/label/sit'
standing = '/home/master/Jibum/Motion_Show/label/stand'
walking = '/home/master/Jibum/Motion_Show/label/walk'

si_ls = os.listdir(sit)
st_ls = os.listdir(standing)
wa_ls = os.listdir(walking)

# %%
si_ls
# Out:
# ['sit_2m170_label.csv',
#  'sit_1m170_label.csv',
#  'sit_3m170_label.csv',
#  'sit_5m170_label.csv',
#  'sit_4m170_label.csv']

# %%
st_ls
# Out:
# ['standing_6m170_label.csv',
#  'standing_5m170_label.csv',
#  'standing_3m170_label.csv',
#  'standing_2m170_label.csv',
#  'standing_4m170_label.csv']

# %%
wa_ls
# Out:
# ['walking_5m170_label.csv',
#  'walking_1m170_label.csv',
#  'walking_2m170_label.csv',
#  'walking_3m170_label.csv',
#  'walking_4m170_label.csv']

# %%
walkSet = pd.DataFrame()

for i in wa_ls:
    df = pd.read_csv(walking + '/' + i)
#     df = df.iloc[:, 4:31]
#     df['label'] = 'sit'
#     df.insert(0, 'label', 'sit')
    walkSet = pd.concat([walkSet, df])

# %%
walkSet
# Out:
#      TimeStamp  Robot_Reference.X  Robot_Reference.Y  Robot_Reference.Z  \
# 0        0.000                  0                  0                  0
# 1        0.008                  0                  0                  0
# 2        0.016                  0                  0                  0
# 3        0.024                  0                  0                  0
# 4        0.032                  0                  0                  0
# ..         ...                ...                ...                ...
# 162      1.296                  0                  0                  0
# 163      1.304                  0                  0                  0
# 164      1.312                  0                  0                  0
# 165      1.320                  0                  0                  0
# 166      1.328                  0                  0                  0
#
#      Robot_Hips.X  Robot_Hips.Y  Robot_Hips.Z  Robot_LeftUpLeg.X  \
# ...

# %%
walkSet.to_csv('/home/master/Jibum/Motion_Show/label/walkSet.csv',index=False,header=True)
test = pd.read_csv('/home/master/Jibum/Motion_Show/label/walkSet.csv')
test
# Out:
#      TimeStamp  Robot_Reference.X  Robot_Reference.Y  Robot_Reference.Z  \
# 0        0.000                  0                  0                  0
# 1        0.008                  0                  0                  0
# 2        0.016                  0                  0                  0
# 3        0.024                  0                  0                  0
# 4        0.032                  0                  0                  0
# ..         ...                ...                ...                ...
# 973      1.296                  0                  0                  0
# 974      1.304                  0                  0                  0
# 975      1.312                  0                  0                  0
# 976      1.320                  0                  0                  0
# 977      1.328                  0                  0                  0
#
#      Robot_Hips.X  Robot_Hips.Y  Robot_Hips.Z  Robot_LeftUpLeg.X  \
# ...

# %%
# import pandas as pd

for i in file_list:
#     print(i)
    data = pd.read_csv(Female + '/' + i)
data
    # print("File name : {0}".format(i))
    # 만약 폴더안에 i값과 일치하는 파일이 있으면 그 파일을 불러와라?
    #with open(Female + '/' + i, 'r', encoding = 'utf-8') as f:
        #reader = csv.reader(f) // 열기
        # TODO : 로직 구현 
        # 수정 로직
        #print(reader)
        # 저장 및 닫기
# Out:
#      TimeStamp  Robot_Reference.X  Robot_Reference.Y  Robot_Reference.Z  \
# 0            0                  0                  0                  0
# 1          578                  0                  0                  0
# 2          657                  0                  0                  0
# 3          703                  0                  0                  0
# 4          735                  0                  0                  0
# ..         ...                ...                ...                ...
# 747      18578                  0                  0                  0
# 748      18610                  0                  0                  0
# 749      18625                  0                  0                  0
# 750      18641                  0                  0                  0
# 751      18672                  0                  0                  0
#
#      Robot_Hips.X  Robot_Hips.Y  Robot_Hips.Z  Robot_LeftUpLeg.X  \
# ...
