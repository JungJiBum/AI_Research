# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv

# %%
# # standing = '/home/master/Jibum/Motion_Show/standing'
# # walking = '/home/master/Jibum/Motion_Show/walking'
# # sitting = '/home/master/Jibum/Motion_Show/sit'
# km_yg = '/home/master/Jibum/Motion_Show/km_yg'

# # st_ls = os.listdir(standing)
# # wa_ls = os.listdir(walking)
# # si_ls = os.listdir(sitting)
# km_yg_ls = os.listdir(km_yg)
# # action = '/home/master/Jibum/Motion_Show/action'
# # ac_ls = os.listdir(action)

motion = '/home/master/Jibum/Motion_Show/motion_set'
mo_ls = os.listdir(motion)
print(mo_ls)
# Out:
# ['act.csv', 'train.csv']

# %%
motion = pd.DataFrame()

for i in mo_ls:
    df = pd.read_csv(motion + '/' + i)
#     df.insert(0,'label','sitting')
    motion = pd.concat([motion, df])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-6d68d2d29f75> in <module>
#       2
#       3 for i in mo_ls:
# ----> 4     df = pd.read_csv(motion + '/' + i)
#       5 #     df.insert(0,'label','sitting')
#       6     motion = pd.concat([motion, df])
#
# ...

# %%
train
# Out:
#         label  TimeStamp  Robot_Reference.X  Robot_Reference.Y  \
# 0     walking         16                  0                  0
# 1     walking         32                  0                  0
# 2     walking        766                  0                  0
# 3     walking        797                  0                  0
# 4     walking        813                  0                  0
# ...       ...        ...                ...                ...
# 7938  standig      14765                  0                  0
# 7939  standig      14781                  0                  0
# 7940  standig      14812                  0                  0
# 7941  standig      14828                  0                  0
# 7942  standig      14844                  0                  0
#
#       Robot_Reference.Z  Robot_Hips.X  Robot_Hips.Y  Robot_Hips.Z  \
# 0                     0      0.001168      1.112907     -0.000418
# 1                     0      0.001328      1.112930     -0.000669
# ...

# %%
train.to_csv('/home/master/Jibum/Motion_Show/km_yg/train.csv',index=False)

# %%
test = pd.read_csv('/home/master/Jibum/Motion_Show/km_yg/train.csv')
test
# Out:
#          label  TimeStamp  Robot_Reference.X  Robot_Reference.Y  \
# 0      walking         16                  0                  0
# 1      walking         32                  0                  0
# 2      walking        766                  0                  0
# 3      walking        797                  0                  0
# 4      walking        813                  0                  0
# ...        ...        ...                ...                ...
# 18167  standig      14765                  0                  0
# 18168  standig      14781                  0                  0
# 18169  standig      14812                  0                  0
# 18170  standig      14828                  0                  0
# 18171  standig      14844                  0                  0
#
#        Robot_Reference.Z  Robot_Hips.X  Robot_Hips.Y  Robot_Hips.Z  \
# 0                      0      0.001168      1.112907     -0.000418
# ...
