# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %%
yj_sit = '/home/master/Jibum/Motion_Show/IMU Data/YJ/sit'
yj_stand = '/home/master/Jibum/Motion_Show/IMU Data/YJ/stand'
yj_walk = '/home/master/Jibum/Motion_Show/IMU Data/YJ/walk'

km_sit = '/home/master/Jibum/Motion_Show/IMU Data/KM/sit'
km_stand = '/home/master/Jibum/Motion_Show/IMU Data/KM/stand'
km_walk = '/home/master/Jibum/Motion_Show/IMU Data/KM/walk'

yg_sit = '/home/master/Jibum/Motion_Show/IMU Data/YG/sit'
yg_stand = '/home/master/Jibum/Motion_Show/IMU Data/YG/stand'
yg_walk = '/home/master/Jibum/Motion_Show/IMU Data/YG/walk'

# %%
# ls = [[yj_sit,yj_stand,yj_walk],[km_sit,km_stand,km_walk],[yg_sit,yg_stand,yg_walk]]

# %%
yjsi_ls = os.listdir(yj_sit)
yjst_ls = os.listdir(yj_stand)
yjwa_ls = os.listdir(yj_walk)

kmsi_ls = os.listdir(km_sit)
kmst_ls = os.listdir(km_stand)
kmwa_ls = os.listdir(km_walk)

ygsi_ls = os.listdir(yg_sit)
ygst_ls = os.listdir(yg_stand)
ygwa_ls = os.listdir(yg_walk)

# %%
sit = pd.DataFrame()

for i in kmsi_ls:
    df = pd.read_csv(km_sit + '/' + i)
    df.insert(0,'label','sit')
    sit = pd.concat([sit, df])

# %%
sit
# Out:
#     label  TimeStamp  Robot_Reference.X  Robot_Reference.Y  Robot_Reference.Z  \
# 0     sit          0                  0                  0                  0
# 1     sit        703                  0                  0                  0
# 2     sit        734                  0                  0                  0
# 3     sit        750                  0                  0                  0
# 4     sit        765                  0                  0                  0
# ..    ...        ...                ...                ...                ...
# 371   sit       6328                  0                  0                  0
# 372   sit       6343                  0                  0                  0
# 373   sit       6359                  0                  0                  0
# 374   sit       6375                  0                  0                  0
# 375   sit       6406                  0                  0                  0
#
# ...

# %%
sit.to_csv('/home/master/Jibum/Motion_Show/IMU Data/KM/kmsit.csv', index=False)

# %%
stand = pd.DataFrame()

for i in kmst_ls:
    df = pd.read_csv(km_stand + '/' + i)
    df.insert(0,'label','stand')
    stand = pd.concat([stand,df])

# %%
stand
# Out:
#      label  TimeStamp  Robot_Reference.X  Robot_Reference.Y  \
# 0    stand         16                  0                  0
# 1    stand        985                  0                  0
# 2    stand       1031                  0                  0
# 3    stand       1047                  0                  0
# 4    stand       1063                  0                  0
# ..     ...        ...                ...                ...
# 735  stand      14765                  0                  0
# 736  stand      14781                  0                  0
# 737  stand      14812                  0                  0
# 738  stand      14828                  0                  0
# 739  stand      14844                  0                  0
#
#      Robot_Reference.Z  Robot_Hips.X  Robot_Hips.Y  Robot_Hips.Z  \
# 0                    0      0.003075      1.111098      0.002113
# 1                    0      0.003201      1.110990      0.001015
# ...

# %%
stand.to_csv('/home/master/Jibum/Motion_Show/IMU Data/KM/kmstand.csv', index=False)

# %%
walk = pd.DataFrame()

for i in kmwa_ls:
    df = pd.read_csv(km_walk + '/' + i)
    df.insert(0,'label','walk')
    walk = pd.concat([walk, df])

# %%
walk
# Out:
#     label  TimeStamp  Robot_Reference.X  Robot_Reference.Y  Robot_Reference.Z  \
# 0    walk         15                  0                  0                  0
# 1    walk        640                  0                  0                  0
# 2    walk        687                  0                  0                  0
# 3    walk        703                  0                  0                  0
# 4    walk        718                  0                  0                  0
# ..    ...        ...                ...                ...                ...
# 279  walk       8266                  0                  0                  0
# 280  walk       8297                  0                  0                  0
# 281  walk       8313                  0                  0                  0
# 282  walk       8328                  0                  0                  0
# 283  walk       8359                  0                  0                  0
#
# ...

# %%
walk.to_csv('/home/master/Jibum/Motion_Show/IMU Data/KM/kmwalk.csv', index=False)
